# %% [markdown]
# ### Estruturas de Sequenciação

# %% [markdown]
# Estrutura if-else

# %%
# Forma alternativa

n = int(input())

r = 'é par' if n % 2 == 0 else 'é impar'

print(n, r)

# %% [markdown]
# ### Matrizes
