# %% [markdown]
# ### Estruturas de Sequenciação

# %% [markdown]
# Estrutura if-else

# %%
# Forma alternativa

n = int(input())

r = 'é par' if n % 2 == 0 else 'é impar'

print(n, r)

# %% [markdown]
# ### Matrizes

# %%
# Construção de uma matriz 3x4, com valor 0 em todas as células

lin = 3
col = 4
matriz = [[0] * col for x in range(lin)]
